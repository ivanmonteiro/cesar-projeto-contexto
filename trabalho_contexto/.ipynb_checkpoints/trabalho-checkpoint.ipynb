# %% [markdown]
# # Contexto IA
# ## Trabalho
# ## Projeto: Context Alimento
#
# Vocês foram designados para fornecer a inteligência do aplicativo "Context Alimento".
#
# A aplicação pega quantos passos o usuário deu

# %%
import numpy as np
import pandas as pd
# from sklearn.model_selection import ShuffleSplit

# Permite visualizar os dados da melhor forma possível
# como estamos utilizando um arquivo HTML, o método display irá exibir uma tabela
# veja mais em: https://ipython.org/ipython-doc/3/api/generated/IPython.display.html#module-IPython.display
from IPython.display import display

# Carregar os dados
full_data = pd.read_csv('housing_data.csv')
prices = full_data['VALOR']
features = full_data.drop('VALOR', axis = 1)
    
display(full_data)
# Out:
#       MQTD   PVIZ   VALOR
# 0    6.575   4.98  504000
# 1    6.421   9.14  453600
# 2    7.185   4.03  728700
# 3    6.998   2.94  701400
# 4    7.147   5.33  760200
# 5    6.430   5.21  602700
# 6    6.012  12.43  480900
# 7    6.172  19.15  569100
# 8    5.631  29.93  346500
# 9    6.004  17.10  396900
# 10   6.377  20.45  315000
# 11   6.009  13.27  396900
# 12   5.889  15.71  455700
# 13   5.949   8.26  428400
# 14   6.096  10.26  382200
# 15   5.834   8.47  417900
# 16   5.935   6.58  485100
# 17   5.990  14.67  367500
# 18   5.456  11.69  424200
# 19   5.727  11.28  382200
# 20   5.570  21.02  285600
# 21   5.965  13.83  411600
# 22   6.142  18.72  319200
# 23   5.813  19.88  304500
# 24   5.924  16.30  327600
# 25   5.599  16.51  291900
# 26   5.813  14.81  348600
# 27   6.047  17.28  310800
# 28   6.495  12.80  386400
# 29   6.674  11.98  441000
# ..     ...    ...     ...
# 459  6.484  18.68  350700
# 460  5.304  24.91  252000
# 461  6.185  18.03  306600
# 462  6.229  13.11  449400
# 463  6.242  10.74  483000
# 464  6.750   7.74  497700
# 465  7.061   7.01  525000
# 466  5.762  10.42  457800
# 467  5.871  13.34  432600
# 468  6.312  10.58  445200
# 469  6.114  14.98  401100
# 470  5.905  11.45  432600
# 471  5.454  18.06  319200
# 472  5.414  23.97  147000
# 473  5.093  29.68  170100
# 474  5.983  18.07  285600
# 475  5.983  13.35  422100
# 476  5.707  12.01  457800
# 477  5.926  13.59  514500
# 478  5.670  17.60  485100
# 479  5.390  21.14  413700
# 480  5.794  14.10  384300
# 481  6.019  12.92  445200
# 482  5.569  15.10  367500
# 483  6.027  14.33  352800
# 484  6.593   9.67  470400
# 485  6.120   9.08  432600
# 486  6.976   5.64  501900
# 487  6.794   6.48  462000
# 488  6.030   7.88  249900
#
# [489 rows x 3 columns]

# %% [markdown]
# ## Dimensões
#
# - **MQTD**: média de quartos
# - **PVIZ**: quantidade em % de vizinhos probres
# - **VALOR**: valor médio da casa

# %% [markdown]
# ## Anális de Dados
#
# ### Calcúle as informações estatísticas padrões para o valor
#
# - existe alguma relação entre o MQTD e o valor?
# - existe alguma relação entre o PVIZ e o valor?

# %%
# TODO: menor valor
minimum_price = 0 #CODE
print ("menor valor:\t ${:,.2f}".format(minimum_price))

# TODO: maior valor
maximum_price = 0 #CODE
print ("maior valor:\t ${:,.2f}".format(maximum_price))

# TODO: valor médio
mean_price = 0 #CODE
print ("valor médio:\t ${:,.2f}".format(mean_price))

# TODO: valor mediano
median_price = 0 #CODE
print ("valor mediano\t ${:,.2f}".format(median_price))

# TODO: desvio padrão
std_price = 0 #CODE
print ("desvio padrão:\t ${:,.2f}".format(std_price))

# TODO: use corr()
# CODE
# Out:
# menor valor:	 $0.00
# maior valor:	 $0.00
# valor médio:	 $0.00
# valor mediano	 $0.00
# desvio padrão:	 $0.00

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 5))
plt.plot(features['MQTD'], prices, 'o')
plt.title('MQTD x VALOR')
plt.xlabel('MQTD')
plt.ylabel('VALOR')
plt.show()

# TODO: monte o gráfico PVIZ x VALOR
#CODE

# %% [markdown]
# ### Resposta
# digite a sua resposta

# %% [markdown]
# ## Desenvolvendo o modelo
#
# - qual foi o melhor score encontrado?
# - qual o melhor modelo?
# - o que a configuração do modelo influência com o overfitting e o underfitting?

# %% [markdown]
# ### split [training set and test set]

# %%
# TODO: Import 'train_test_split'
#CODE

# TODO: crie o training set e o test set da forma 80% - 20%, random_state = 42 (porque?)
X_train, X_test, y_train, y_test = [], [], [], [] #CODE

# %% [markdown]
# ### criando o modelo

# %% [markdown]
# #### NeuralNetwork

# %%
# TODO: Import 'MLPRegressor'


# TODO: crie uma instancia do modelo do tipo MLPRegressor com solver = 'lbfgs' (porque?), random_state = 42 (porque?)
model = 0 #code

# TODO: treine o modelo
#CODE

# TODO: imprima o score do treino o do teste
#CODE

# %% [markdown]
# #### KnN
#
# - compare o resultado da rede neural com o do KnN
# - teste diferentes n_neighbors

# %%
# TODO: Import 'KNeighborsRegressor'
#CODE

# TODO: crie uma instancia do modelo do tipo KNeighborsRegressor
model = 0 #CODE

# TODO: treine o modelo
#CODE

# TODO: imprima o score do treino o do teste
#CODE

# %% [markdown]
# #### Essembler (AdaBuster)
#
# - compare o resultados com os demais

# %%
# TODO: Import 'AdaBoostRegressor'
from sklearn.ensemble import AdaBoostRegressor

# TODO: crie uma instancia do modelo do tipo AdaBoostRegressor com random_state = 42
model = AdaBoostRegressor(loss='exponential', n_estimators=1, random_state=42)

# TODO: treine o modelo
model.fit(X_train, y_train)

# TODO: imprima o score do treino o do teste
print ('training score:\t', model.score(X_train, y_train))
print ('test score:\t', model.score(X_test, y_test))
# Out:
# training score:	 0.806356592892
# test score:	 0.7764457097

# %% [markdown]
# ### Bias x Variance

# %%
# TODO: Import 'KNeighborsRegressor'
from sklearn.neighbors import KNeighborsRegressor

# TODO: crie uma instancia do modelo do tipo KNeighborsRegressor n_neighbors = n
# TODO: treine o modelo e adicione os scores nos arrays
train_scores = []
test_scores = []
n = 25
for i in range(1, n):
    0#CODE

# TODO: imprima o gráfico train_scores x test_scores
plt.figure(figsize=(10, 10))
plt.plot(range(1, n), train_scores)
plt.plot(range(1, n), test_scores)
plt.title('n x score')
plt.xlabel('score')
plt.ylabel('n')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-7eba34a04bd4> in <module>()
#      12 # TODO: imprima o gráfico train_scores x test_scores
#      13 plt.figure(figsize=(10, 10))
# ---> 14 plt.plot(range(1, n), train_scores)
#      15 plt.plot(range(1, n), test_scores)
#      16 plt.title('n x score')
#
# ~/.virtualenvs/ml3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3238                       mplDeprecation)
#    3239     try:
# -> 3240         ret = ax.plot(*args, **kwargs)
#    3241     finally:
#    3242         ax._hold = washold
#
# ~/.virtualenvs/ml3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
#    1711         pre_doc = inner.__doc__
#    1712         if pre_doc is None:
#
# ~/.virtualenvs/ml3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1435         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1436
# -> 1437         for line in self._get_lines(*args, **kwargs):
#    1438             self.add_line(line)
#    1439             lines.append(line)
#
# ~/.virtualenvs/ml3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     402                 this += args[0],
#     403                 args = args[1:]
# --> 404             for seg in self._plot_args(this, kwargs):
#     405                 yield seg
#     406
#
# ~/.virtualenvs/ml3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     382             x, y = index_of(tup[-1])
#     383
# --> 384         x, y = self._xy_from_xy(x, y)
#     385
#     386         if self.command == 'plot':
#
# ~/.virtualenvs/ml3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     241         if x.shape[0] != y.shape[0]:
#     242             raise ValueError("x and y must have same first dimension, but "
# --> 243                              "have shapes {} and {}".format(x.shape, y.shape))
#     244         if x.ndim > 2 or y.ndim > 2:
#     245             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (24,) and (0,)

# %% [markdown]
# ### Resposta
# digite a sua resposta
